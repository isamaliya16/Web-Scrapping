# %%
import requests
from bs4 import BeautifulSoup

# CATEGORY LINKS
CATEGORIES = {
    "gujarat": "https://www.divyabhaskar.co.in/local/gujarat/",
    "cricket": "https://www.divyabhaskar.co.in/sports/cricket/",
    "entertainment": "https://www.divyabhaskar.co.in/entertainment/"
}

CITY_LINKS = {
    "ahmedabad": "https://www.divyabhaskar.co.in/local/gujarat/ahmedabad/",
    "surat": "https://www.divyabhaskar.co.in/local/gujarat/surat/",
    "vadodara": "https://www.divyabhaskar.co.in/local/gujarat/vadodara/",
    "rajkot": "https://www.divyabhaskar.co.in/local/gujarat/rajkot/",
    "bhavnagar": "https://www.divyabhaskar.co.in/local/gujarat/bhavnagar/"
}

# FUNCTION: FETCH NEWS
def fetch_news(url, top=10):
    headers = {"User-Agent": "Mozilla/5.0"}
    res = requests.get(url, headers=headers)

    if res.status_code != 200:
        print("Failed:", res.status_code)
        return []

    soup = BeautifulSoup(res.text, "html.parser")
    items = soup.find_all(["h2", "h3"], limit=50)

    unique = []
    seen = set()

    for h in items:
        title = h.get_text(strip=True)
        a = h.find_parent("a")
        if not a or not a.get("href"):
            continue

        link = a["href"]
        if link.startswith("/"):
            link = "https://www.divyabhaskar.co.in" + link

        # avoid duplicates
        if link in seen:
            continue

        seen.add(link)
        unique.append((title, link))

        if len(unique) == top:
            break

    return unique

# MAIN PROGRAM
def main():
    print("\n📌 OPTIONS:")
    print("1. Top 10 News (Gujarat)")
    print("2. My City News")
    print("3. Gujarat News")
    print("4. Cricket News")
    print("5. Entertainment News")

    choice = input("\nSelect option (1-5): ").strip()

    if choice == "1":     # Top 10 Gujarat
        url = CATEGORIES["gujarat"]

    elif choice == "2":   # My City
        print("\nAvailable Cities:", ", ".join(CITY_LINKS))
        city = input("Enter city name: ").lower().strip()
        if city not in CITY_LINKS:
            print("City not found!")
            return
        url = CITY_LINKS[city]

    elif choice == "3":
        url = CATEGORIES["gujarat"]

    elif choice == "4":
        url = CATEGORIES["cricket"]

    elif choice == "5":
        url = CATEGORIES["entertainment"]

    else:
        print("Invalid option!")
        return

    print("\nFetching latest news...\n")

    news = fetch_news(url, top=10)

    if not news:
        print("No news found.")
        return

    for i, (title, link) in enumerate(news, start=1):
        print(f"{i}. {title}\n   {link}\n")


# Run
main()
# Out:
# 📌 OPTIONS:
# 1. Top 10 News (Gujarat)
# 2. My City News
# 3. Gujarat News
# 4. Cricket News
# 5. Entertainment News
# Select option (1-5):  2
# Available Cities: ahmedabad, surat, vadodara, rajkot, bhavnagar
# Enter city name:  surat
# Fetching latest news...
#
# 1. દક્ષિણ ગુજરાતના પરીક્ષાર્થીઓને અમદાવાદનો ધક્કો નહીં:સુરતમાં 5 સેન્ટર પર UPSCની પરીક્ષામાં ચેકીંગ બાદ પ્રવેશ અપાયો, કેટલાક મોડા પડતા પ્રવેશ ન અપાયો
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/no-push-from-ahmedabad-for-south-gujarat-exam-candidates-136547923.html
#
# 2. ગુજરાત પોલીસમાં 13,591 પોસ્ટ પર ભરતી:PSIની 858 અને લોકરક્ષકની 12733 જગ્યા માટે ઉમેદવારો 3થી 23 ડિસેમ્બર સુધી અરજી કરી શકશે
#    https://www.divyabhaskar.co.in/local/gujarat/gandhinagar/news/gujarat-police-bharti-13591-psi-lrd-recruitment-apply-online-136547683.html
#
# 3. 16.8 ડિગ્રી તાપમાન સાથે અમરેલી-વડોદરા સૌથી ઠંડા:24 કલાકમાં નલિયામાં ગરમીનો પારો 2.6 ડિગ્રી ઊંચકાયો, મહાનગરોનું તાપમાન ગગડ્યું
#    https://www.divyabhaskar.co.in/local/gujarat/ahmedabad/news/minimum-temperature-in-naliya-increased-by-26-degrees-celsius-in-the-last-24-hours-136547847.html
#
# 4. 'ગેરકાયદે દબાણો તોડી નાખો, ડિમોલિશન કરી દો':વરાછાની સમસ્યાઓને સોલ્વ કરવા મેયર-કમિશનર મેદાનમાં ઊતર્યા, લાલઘૂમ થઈને અધિકારીઓને ખખડાવ્યા
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/demolish-the-illegal-structures-im-talking-straight-136541691.html
#
# 5. ‘પોઝિટિવ’ ટ્યુશન ક્લાસીસનો 'નેગેટિવ' ગુરૂ:પૂર્વ વિદ્યાર્થિનીનું ઈન્સ્ટામાં ફેક ID બનાવી બ્લેકમેલ કરી; વ્હોટ્સએપ ગ્રુપમાં યુવતીના પરિવારને એડ કરી મોર્ફ કરેલા અશ્લીલ ફોટા મૂક્યાં
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/teacher-caught-defaming-former-student-with-morphed-photos-using-fake-id-blackmailing-her-with-virtual-number-136541679.html
#
# 6. ભાસ્કર બ્રેકિંગ:અમદાવાદમાં ‘ન્યૂયોર્ક ટાઇમ્સ સ્કેવર’ જેવી ઇમારત, ગાંધીનગરમાં શોપિંગ બેલ્ટ, સુરતમાં બીચ ટુરિઝમ થશે
#    https://www.divyabhaskar.co.in/local/gujarat/gandhinagar/news/there-will-be-a-building-like-new-york-times-square-in-ahmedabad-a-shopping-belt-in-gandhinagar-and-beach-tourism-in-surat-136545587.html
#
# 7. સુરતના કવાસ ક્રિકેટ ગ્રાઉન્ડમાંથી નવજાત બાળકી મળી:મોડીરાતે રડવાનો અવાજ સાંભળી લોકો દોડ્યા, માસૂમ ICUમાં દાખલ; નિર્દયી માતા-પિતાને શોધનારને 11,000નું ઇનામ
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/shocking-news-as-newborn-baby-found-at-cricket-ground-136540304.html
#
# 8. ભાસ્કર એક્સક્લુસિવ:ન્યાય મેળવવા તક્ષશિલાના વાલીઓના 3 કરોડ ખર્ચાઈ જતાં 5 વર્ષે વળતર માંગ્યુ
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/taxila-parents-seek-compensation-after-spending-rs-3-crore-to-get-justice-for-5-years-136546876.html
#
# 9. 'કોઈ બીજા માતા-પિતાને મારી જેવી પીડા ન સહેવી પડે':તક્ષશિલા અગ્નિકાંડના પીડિતે સુપ્રીમ કોર્ટમાં PIL દાખલ કરી, ફાયર સેફ્ટી નિષ્ફળતાઓની તપાસ માટે જ્યુડિશિયલ કમિશન રચવા અપીલ​
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/pil-in-supreme-court-to-prevent-premature-death-of-other-peoples-children-some-important-demands-to-improve-emergency-systems-across-the-country-136543486.html
#
# 10. સિટી એન્કર:વિશ્વનો કોઈ પણ બાયર સુરતની જ્વેલરી ઉત્પાદક કંપનીથી સીધા સોદા કરી શકશે, આવવા-જવાનો ખર્ચ સંસ્થા ચૂકવશે
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/any-buyer-from-around-the-world-will-be-able-to-deal-directly-with-a-surat-based-jewelry-manufacturing-company-and-the-organization-will-pay-for-travel-expenses-136546895.html
