# %%
import requests
from bs4 import BeautifulSoup

# -------------------------------
# CATEGORY LINKS
# -------------------------------
CATEGORIES = {
    "gujarat": "https://www.divyabhaskar.co.in/local/gujarat/",
    "cricket": "https://www.divyabhaskar.co.in/sports/cricket/",
    "entertainment": "https://www.divyabhaskar.co.in/entertainment/"
}

CITY_LINKS = {
    "ahmedabad": "https://www.divyabhaskar.co.in/local/gujarat/ahmedabad/",
    "surat": "https://www.divyabhaskar.co.in/local/gujarat/surat/",
    "vadodara": "https://www.divyabhaskar.co.in/local/gujarat/vadodara/",
    "rajkot": "https://www.divyabhaskar.co.in/local/gujarat/rajkot/",
    "bhavnagar": "https://www.divyabhaskar.co.in/local/gujarat/bhavnagar/"
}

# -------------------------------
# FUNCTION: FETCH NEWS
# -------------------------------
def fetch_news(url, top=10):
    headers = {"User-Agent": "Mozilla/5.0"}
    res = requests.get(url, headers=headers)

    if res.status_code != 200:
        print("Failed:", res.status_code)
        return []

    soup = BeautifulSoup(res.text, "html.parser")
    items = soup.find_all(["h2", "h3"], limit=50)

    unique = []
    seen = set()

    for h in items:
        title = h.get_text(strip=True)
        a = h.find_parent("a")
        if not a or not a.get("href"):
            continue

        link = a["href"]
        if link.startswith("/"):
            link = "https://www.divyabhaskar.co.in" + link

        # avoid duplicates
        if link in seen:
            continue

        seen.add(link)
        unique.append((title, link))

        if len(unique) == top:
            break

    return unique

# -------------------------------
# MAIN PROGRAM
# -------------------------------
def main():
    print("\n📌 OPTIONS:")
    print("1. Top 10 News (Gujarat)")
    print("2. My City News")
    print("3. Gujarat News")
    print("4. Cricket News")
    print("5. Entertainment News")

    choice = input("\nSelect option (1-5): ").strip()

    if choice == "1":     # Top 10 Gujarat
        url = CATEGORIES["gujarat"]

    elif choice == "2":   # My City
        print("\nAvailable Cities:", ", ".join(CITY_LINKS))
        city = input("Enter city name: ").lower().strip()
        if city not in CITY_LINKS:
            print("City not found!")
            return
        url = CITY_LINKS[city]

    elif choice == "3":
        url = CATEGORIES["gujarat"]

    elif choice == "4":
        url = CATEGORIES["cricket"]

    elif choice == "5":
        url = CATEGORIES["entertainment"]

    else:
        print("Invalid option!")
        return

    print("\nFetching latest news...\n")

    news = fetch_news(url, top=10)

    if not news:
        print("No news found.")
        return

    for i, (title, link) in enumerate(news, start=1):
        print(f"{i}. {title}\n   {link}\n")


# Run
main()
# Out:
# 📌 OPTIONS:
# 1. Top 10 News (Gujarat)
# 2. My City News
# 3. Gujarat News
# 4. Cricket News
# 5. Entertainment News
# Select option (1-5):  5
# Fetching latest news...
#
# 1. અશનૂર કૌરે તાન્યા પર કાવડ ફેંક્યું?:બિગ બોસની પૂર્વ કન્ટેસ્ટન્ટ કામ્યા પંજાબીએ તેના વર્તનની ટીકા કરી; વીડિયો વાયરલ થયા બાદ અશનૂરના એવિક્શનની માંગ ઊઠી
#    https://www.divyabhaskar.co.in/entertainment/news/ashnoor-kaur-tanisha-bigg-boss-controversy-threw-locket-eviction-demand-136534383.html
#
# 2. રણવીર સિંહની 'ધુરંધર' રિલીઝ પહેલાં વિવાદમાં સપડાઈ:શહીદ મેજર મોહિત શર્માના માતા-પિતાએ દિલ્લી હાઇકોર્ટમાં અરજી કરી ફિલ્મ પર પ્રતિબંધ મૂકવાની માંગ કરી
#    https://www.divyabhaskar.co.in/entertainment/news/ranveer-singh-dhurandhar-controversy-major-mohit-sharma-parents-ban-136534229.html
#
# 3. 'રંગીલા' માટે શ્રીદેવી પછી ઉર્મિલા જ મગજમાં હતી':રામ ગોપાલ વર્માએ કહ્યું- આમિરને મનફાવે તેમ કરવાની છૂટ આપી હતી; જેકીની જગ્યાએ બીજું કોઈ આ રોલ કરી જ ન શકત
#    https://www.divyabhaskar.co.in/entertainment/news/rangeela-re-release-ram-gopal-varma-urmila-sridevi-aamir-jackie-shroff-136531639.html
#
# 4. 'અન્ના'એ સાઉથ સિનેમાથી દૂરનું કારણ જણાવ્યું!:સુનીલ શેટ્ટીએ કહ્યું- 'બોલિવૂડ હીરોને ત્યાં વિલનનો રોલ આપે છે, મને આ વાત જરાય પસંદ નથી'
#    https://www.divyabhaskar.co.in/entertainment/news/sunil-shetty-explained-the-reason-for-his-distance-from-south-cinema-136533826.html
#
# 5. 'અજય દેવગનના ફોટો-અવાજનો ખોટો ઉપયોગ બંધ કરો':કોર્ટે કહ્યું – 'મંજૂરી વિના ઉપયોગ કરવો ગેરકાયદે, વાંધાજનક સામગ્રી તાત્કાલિક હટાવવા'
#    https://www.divyabhaskar.co.in/entertainment/news/ajay-devgn-gets-relief-from-delhi-high-court-on-obscene-deepfake-case-136532671.html
#
# 6. 'આજ ભી જી કરતા હૈ...':ધર્મેન્દ્રની છેલ્લી ફિલ્મ- છેલ્લી કવિતા, ‘ઇક્કીસ’ના મેકર્સે વીડિયો શેર કર્યો; અસરાનીની ઝલક અને એક્ટરના શબ્દો આંખો ભીની કરી દેશે
#    https://www.divyabhaskar.co.in/entertainment/news/dharmendra-poem-in-last-movie-ikkis-video-136532167.html
#
# 7. ‘તેરે ઇશ્ક મેં’ ભાવનાત્મક અને તોફાની પ્રેમ કહાની:દમદાર અભિનય; સંગીત સુંદર પણ યાદગાર નહીં; ઘટનાઓ જરૂરિયાત કરતાં વધુ સિનેમેટિક; લંબાણ ખૂંચે છે
#    https://www.divyabhaskar.co.in/entertainment/news/tere-ishq-mein-film-review-aanand-l-rai-emotional-love-powerful-acting-136532619.html
#
# 8. 'દ્રશ્યમ' ફેમ શ્રેયા સરન બની ડીપફેકનો શિકાર!:એક્ટ્રેસે કહ્યું- મારા ફોટો સાથે બનાવટ કરી, લોકોને મારા નામે છેતર્યા; 'એવા ફોટો ફરે છે, પરિવાર પણ નથી ઓળખી શકતું'
#    https://www.divyabhaskar.co.in/entertainment/news/actress-shriya-sarans-photos-are-being-tampered-with-136532071.html
#
# 9. 'આ છે અમારી રાજકુમારી સરાયાહ મલ્હોત્રા':સિદ્ધાર્થ -કિયારાએ પુત્રીનું નામકરણ કર્યું; કપલે લાડલીના જન્મના 3 મહિના બાદ પહેલી ઝલક બતાવી
#    https://www.divyabhaskar.co.in/entertainment/news/sidharth-kiara-advani-daughter-name-sarayah-first-glimpse-136531929.html
#
# 10. દિલ્હીમાં '120 બહાદુર' આજથી ટેક્સ ફ્રી!:મુખ્યમંત્રી રેખા ગુપ્તાએ કરી જાહેરાત, એક્ટર-પ્રોડ્યુસર ફરહાન અખ્તરે આભાર માન્યો
#    https://www.divyabhaskar.co.in/entertainment/news/farhan-akhtars-film-120-bahadur-is-tax-free-in-delhi-from-today-cm-rekha-gupta-announce-136531922.html
