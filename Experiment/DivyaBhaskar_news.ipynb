# %%
import requests
from bs4 import BeautifulSoup

# -------------------------------
# CATEGORY LINKS
# -------------------------------
CATEGORIES = {
    "gujarat": "https://www.divyabhaskar.co.in/local/gujarat/",
    "cricket": "https://www.divyabhaskar.co.in/sports/cricket/",
    "entertainment": "https://www.divyabhaskar.co.in/entertainment/"
}

CITY_LINKS = {
    "ahmedabad": "https://www.divyabhaskar.co.in/local/gujarat/ahmedabad/",
    "surat": "https://www.divyabhaskar.co.in/local/gujarat/surat/",
    "vadodara": "https://www.divyabhaskar.co.in/local/gujarat/vadodara/",
    "rajkot": "https://www.divyabhaskar.co.in/local/gujarat/rajkot/",
    "bhavnagar": "https://www.divyabhaskar.co.in/local/gujarat/bhavnagar/"
}

# -------------------------------
# FUNCTION: FETCH NEWS
# -------------------------------
def fetch_news(url, top=10):
    headers = {"User-Agent": "Mozilla/5.0"}
    res = requests.get(url, headers=headers)

    if res.status_code != 200:
        print("Failed:", res.status_code)
        return []

    soup = BeautifulSoup(res.text, "html.parser")
    items = soup.find_all(["h2", "h3"], limit=50)

    unique = []
    seen = set()

    for h in items:
        title = h.get_text(strip=True)
        a = h.find_parent("a")
        if not a or not a.get("href"):
            continue

        link = a["href"]
        if link.startswith("/"):
            link = "https://www.divyabhaskar.co.in" + link

        # avoid duplicates
        if link in seen:
            continue

        seen.add(link)
        unique.append((title, link))

        if len(unique) == top:
            break

    return unique

# -------------------------------
# MAIN PROGRAM
# -------------------------------
def main():
    print("\n📌 OPTIONS:")
    print("1. Top 10 News (Gujarat)")
    print("2. My City News")
    print("3. Gujarat News")
    print("4. Cricket News")
    print("5. Entertainment News")

    choice = input("\nSelect option (1-5): ").strip()

    if choice == "1":     # Top 10 Gujarat
        url = CATEGORIES["gujarat"]

    elif choice == "2":   # My City
        print("\nAvailable Cities:", ", ".join(CITY_LINKS))
        city = input("Enter city name: ").lower().strip()
        if city not in CITY_LINKS:
            print("City not found!")
            return
        url = CITY_LINKS[city]

    elif choice == "3":
        url = CATEGORIES["gujarat"]

    elif choice == "4":
        url = CATEGORIES["cricket"]

    elif choice == "5":
        url = CATEGORIES["entertainment"]

    else:
        print("Invalid option!")
        return

    print("\nFetching latest news...\n")

    news = fetch_news(url, top=10)

    if not news:
        print("No news found.")
        return

    for i, (title, link) in enumerate(news, start=1):
        print(f"{i}. {title}\n   {link}\n")


# Run
main()
# Out:
# 📌 OPTIONS:
# 1. Top 10 News (Gujarat)
# 2. My City News
# 3. Gujarat News
# 4. Cricket News
# 5. Entertainment News
# Select option (1-5):  2
# Available Cities: ahmedabad, surat, vadodara, rajkot, bhavnagar
# Enter city name:  surat
# Fetching latest news...
#
# 1. ‘પોઝિટિવ’ ટ્યુશન ક્લાસીસનો 'નેગેટિવ' ગુરૂ:પૂર્વ વિદ્યાર્થિનીનું ઈન્સ્ટામાં ફેક ID બનાવી બ્લેકમેલ કરી; વ્હોટ્સએપ ગ્રુપમાં યુવતીના પરિવારને એડ કરી મોર્ફ કરેલા અશ્લીલ ફોટા મૂક્યાં
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/teacher-caught-defaming-former-student-with-morphed-photos-using-fake-id-blackmailing-her-with-virtual-number-136541679.html
#
# 2. સુરતના કવાસ ક્રિકેટ ગ્રાઉન્ડમાંથી નવજાત બાળકી મળી:મોડીરાતે રડવાનો અવાજ સાંભળી લોકો દોડ્યા, માસૂમ ICUમાં દાખલ; નિર્દયી માતા-પિતાને શોધનારને 11,000નું ઇનામ
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/shocking-news-as-newborn-baby-found-at-cricket-ground-136540304.html
#
# 3. પતંગની લાયમાં 12 વર્ષનો કિશોર દીવાલ નીચે દટાયો:છાતી પર દીવાલનો મોટો ભાગ પડતાં મોતને ભેટ્યો, 3 ભાઈ-બહેનમાં સૌથી નાના ભાઈનાં મોતથી પરિવારમાં શોક
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/surat-limbayat-uttarayan-tragedy-boy-dies-wall-collapse-136539412.html
#
# 4. માવઠાંની આગાહી વચ્ચે વાદળછાયું વાતાવરણ:24 કલાકમાં નલિયાના તાપમાનમાં 1.4 ડિગ્રીનો વધારો; ડિસેમ્બરમાં 10 દિવસ કમોસમી વરસાદની વકી
#    https://www.divyabhaskar.co.in/local/gujarat/ahmedabad/news/cloudy-weather-amid-forecast-of-heavy-rain-temperature-in-nalia-rises-by-14-in-24-hours-136539577.html
#
# 5. 3 વર્ષથી તૈયાર માર્કેટનું ઉદ્ઘાટન ન થતા ખંડેર હાલત:કરોડોના ખર્ચે બનેલી સુરતની ફિશ માર્કેટમાંથી અજાણ્યા ઇસમની લાશ મળી, દારૂ-ડ્રગ્સનો અડ્ડો બન્યાના આક્ષેપ
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/the-market-which-has-not-been-inaugurated-for-3-years-is-in-a-dilapidated-condition-136540752.html
#
# 6. 'ગેરકાયદે દબાણો તોડી નાખો, ડિમોલિશન કરી દો':વરાછાની સમસ્યાઓને સોલ્વ કરવા મેયર-કમિશનર મેદાનમાં ઊતર્યા, લાલઘૂમ થઈને અધિકારીઓને ખખડાવ્યા
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/demolish-the-illegal-structures-im-talking-straight-136541691.html
#
# 7. માવઠાથી ખેડૂતોને 30 કરોડનો ફટકો:સુરત જિલ્લામાં ડાંગરના ઉત્પાદનમાં બે લાખ બોરીનો જંગી ઘટાડો, ખર્ચની સામે સરકારી સહાય અપૂરતીઃ મનહર પટેલ
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/massive-drop-of-two-lakh-sacks-in-paddy-production-in-surat-district-farmers-suffer-a-blow-of-rs-30-crore-136540498.html
#
# 8. સુરતમાં બ્રિજ નીચે નશાના કારોબારના વીડિયો બાદ તંત્ર જાગ્યું:વરાછાથી સરથાણા સુધી ગેરકાયદે રહેતા 250થી વધુ લોકોને હટાવાયા, દબાણો દૂર કરાયાં
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/surat-sarthana-bridge-drugs-gambling-viral-video-136531089.html
#
# 9. સુરત એરપોર્ટ પર DG યાત્રા સ્ટાફની માસ લીવ:પગાર ન મળતા 35 કર્મચારીઓ હડતાળ પર, પેસેન્જરોને ભારે હાલાકીનો સામનો કરવો પડ્યો
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/dg-yatra-staff-on-mass-leave-at-surat-airport-136535584.html
#
# 10. એક જ દિવસમાં 1097 વાહનચાલકોના લાયસન્સ રદ કરવા ભલામણ:બે વેપારીઓ સાથે 61 લાખની છેતરપિંડી, કોડેન સિરપનું વેચાણ કરતી મહિલા ઝડપાઇ
#    https://www.divyabhaskar.co.in/local/gujarat/surat/news/license-of-1097-will-be-cancelled-woman-caught-cheating-two-traders-of-rs-61-lakh-and-selling-codeine-syrup-136535832.html
